# %%
import requests
APP_ID = "c100d73c"
APP_KEY = "30aaf697a5de6a09ec78d37c70df8423"
url = "https://api.adzuna.com/v1/api/jobs/gb/version"
r = requests.get(url, params={"app_id": APP_ID, "app_key": APP_KEY, "content-type":"application/json"})
print(r.json())
# Out:
# {'doc': 'https://api.adzuna.com/v1/doc', '__CLASS__': 'Adzuna::API::Response::Exception', 'display': "Unknown API end-point called: 'jobs/gb/version'", 'exception': 'UNKNOWN_METHOD'}

# %%
import requests, pandas as pd

base = "https://api.adzuna.com/v1/api/jobs/us/search/1"
params = {
  "app_id": APP_ID,
  "app_key": APP_KEY,
  "what": "data scientist OR machine learning engineer",
  "results_per_page": 50,
  "content-type": "application/json"
}
res = requests.get(base, params=params).json()
df = pd.json_normalize(res["results"])
print(df[["id","title","company.display_name","location.area","created","salary_min","salary_max"]].head())
# Out:
#            id                                              title  \
# 0  5404361540         Data Scientist / Machine Learning Engineer
# 1  5342363020  Founding Data Scientist / Machine Learning Eng...
# 2  5344734501  Sr. Principal Data Scientist / Machine Learnin...
# 3  5363530536  Data Scientist/Machine Learning Engineer - Res...
# 4  5464494122  (USA) Senior, Data Scientist - Machine Learnin...
#
#   company.display_name                                    location.area  \
# 0     Think Tank, Inc.          [US, Florida, Leon County, Tallahassee]
# 1          Palladio AI                                             [US]
# 2              Ascentt                [US, Texas, Collin County, Plano]
# 3               Bowman           [US, Virginia, Fairfax County, Reston]
# 4              Walmart  [US, California, Santa Clara County, Sunnyvale]
#
#                 created  salary_min  salary_max
# 0  2025-09-17T22:06:31Z   108516.75   108516.75
# 1  2025-08-07T16:11:02Z   272013.00   272013.00
# 2  2025-08-08T19:19:55Z        3.00        5.00
# 3  2025-08-22T09:18:25Z   106158.15   106158.15
# 4  2025-10-25T14:39:00Z   164742.10   164742.10

# %%
df.head()
# Out:
#                                          description   latitude  \
# 0  *Authorized to work in the US Required *Remote...  30.419215
# 1  Seeking Founding Data Scientists and Machine L...        NaN
# 2  Job Summary We're looking for an exceptionally...  33.060381
# 3  Short Description Bowman has an opportunity fo...  38.952067
# 4  Position Summary What you'll do The Data Scien...  37.376099
#
#                                         redirect_url          id  \
# 0  https://www.adzuna.com/details/5404361540?utm_...  5404361540
# 1  https://www.adzuna.com/details/5342363020?utm_...  5342363020
# 2  https://www.adzuna.com/details/5344734501?utm_...  5344734501
# 3  https://www.adzuna.com/details/5363530536?utm_...  5363530536
# 4  https://www.adzuna.com/land/ad/5464494122?se=E...  5464494122
#
#                                                title   longitude  salary_min  \
# 0         Data Scientist / Machine Learning Engineer  -84.233597   108516.75
# 1  Founding Data Scientist / Machine Learning Eng...         NaN   272013.00
# 2  Sr. Principal Data Scientist / Machine Learnin...  -96.733343        3.00
# 3  Data Scientist/Machine Learning Engineer - Res...  -77.345174   106158.15
# 4  (USA) Senior, Data Scientist - Machine Learnin... -122.021940   164742.10
#
#                                                adref  salary_max  \
# 0  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQwNDM2MTU0MCIsI...   108516.75
# 1  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTM0MjM2MzAyMCIsI...   272013.00
# 2  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTM0NDczNDUwMSIsI...        5.00
# 3  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiRUtnR1FXZTY4QkdLQ...   106158.15
# 4  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQ2NDQ5NDEyMiIsI...   164742.10
#
#                     __CLASS__  ...               location.__CLASS__  \
# 0  Adzuna::API::Response::Job  ...  Adzuna::API::Response::Location
# 1  Adzuna::API::Response::Job  ...  Adzuna::API::Response::Location
# 2  Adzuna::API::Response::Job  ...  Adzuna::API::Response::Location
# 3  Adzuna::API::Response::Job  ...  Adzuna::API::Response::Location
# 4  Adzuna::API::Response::Job  ...  Adzuna::API::Response::Location
#
#            location.display_name  \
# 0       Tallahassee, Leon County
# 1                             US
# 2           Plano, Collin County
# 3         Reston, Fairfax County
# 4  Sunnyvale, Santa Clara County
#
#                                      location.area company.display_name  \
# 0          [US, Florida, Leon County, Tallahassee]     Think Tank, Inc.
# 1                                             [US]          Palladio AI
# 2                [US, Texas, Collin County, Plano]              Ascentt
# 3           [US, Virginia, Fairfax County, Reston]               Bowman
# 4  [US, California, Santa Clara County, Sunnyvale]              Walmart
#
#                 company.__CLASS__ category.tag  \
# 0  Adzuna::API::Response::Company      it-jobs
# 1  Adzuna::API::Response::Company      it-jobs
# 2  Adzuna::API::Response::Company      it-jobs
# 3  Adzuna::API::Response::Company      it-jobs
# 4  Adzuna::API::Response::Company      it-jobs
#
#                 category.__CLASS__ category.label contract_time contract_type
# 0  Adzuna::API::Response::Category        IT Jobs           NaN           NaN
# 1  Adzuna::API::Response::Category        IT Jobs     full_time           NaN
# 2  Adzuna::API::Response::Category        IT Jobs     full_time           NaN
# 3  Adzuna::API::Response::Category        IT Jobs           NaN           NaN
# 4  Adzuna::API::Response::Category        IT Jobs           NaN           NaN
#
# [5 rows x 22 columns]
